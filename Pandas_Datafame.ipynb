# %% [markdown]
# <a href="https://colab.research.google.com/github/hrutik016/30-days-of-ML-using-MATLAB/blob/master/Pandas_Datafame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataframe

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    'Population': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067
    ],
    'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]
}, columns=['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'])

# %%
df
# Out:
#    Population       GDP  Surface Area    HDI Continent
# 0      35.467   1785387       9984670  0.913   America
# 1      63.951   2833687        640679  0.888    Europe
# 2      80.940   3874437        357114  0.916    Europe
# 3      60.665   2167744        301336  0.873    Europe
# 4     127.061   4602367        377930  0.891      Asia
# 5      64.511   2950039        242495  0.907    Europe
# 6     318.523  17348075       9525067  0.915   America

# %%
df.index = [
    'Canada',
    'France',
    'Germany',
    'Italy',
    'Japan',
    'United Kingdom',
    'United States',
]

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %%
df.values
# Out:
# array([[35.467, 1785387, 9984670, 0.913, 'America'],
#        [63.951, 2833687, 640679, 0.888, 'Europe'],
#        [80.94, 3874437, 357114, 0.916, 'Europe'],
#        [60.665, 2167744, 301336, 0.873, 'Europe'],
#        [127.061, 4602367, 377930, 0.891, 'Asia'],
#        [64.511, 2950039, 242495, 0.907, 'Europe'],
#        [318.523, 17348075, 9525067, 0.915, 'America']], dtype=object)

# %%
df.index
# Out:
# Index(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom',
#        'United States'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to United States
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    7 non-null      float64
#  1   GDP           7 non-null      int64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 336.0+ bytes

# %%
df.size
# Out:
# 35

# %%
df.shape
# Out:
# (7, 5)

# %%
df.describe()
# Out:
#        Population           GDP  Surface Area       HDI
# count    7.000000  7.000000e+00  7.000000e+00  7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429
# std     97.249970  5.494020e+06  4.576187e+06  0.016592
# min     35.467000  1.785387e+06  2.424950e+05  0.873000
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000
# max    318.523000  1.734808e+07  9.984670e+06  0.916000

# %%
df.dtypes
# Out:
# Population      float64
# GDP               int64
# Surface Area      int64
# HDI             float64
# Continent        object
# dtype: object

# %%
df.dtypes.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of Population      float64
# GDP               int64
# Surface Area      int64
# HDI             float64
# Continent        object
# dtype: object>

# %%
df.loc['Canada']
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.iloc[0]
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.iloc[-1]
# Out:
# Population       318.523
# GDP             17348075
# Surface Area     9525067
# HDI                0.915
# Continent        America
# Name: United States, dtype: object

# %%
df['GDP']
# Out:
# Canada             1785387
# France             2833687
# Germany            3874437
# Italy              2167744
# Japan              4602367
# United Kingdom     2950039
# United States     17348075
# Name: GDP, dtype: int64

# %%
df['Population']
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: Population, dtype: float64

# %%
df['Population'].to_frame()
# Out:
#                 Population
# Canada              35.467
# France              63.951
# Germany             80.940
# Italy               60.665
# Japan              127.061
# United Kingdom      64.511
# United States      318.523

# %%
df[['Population', 'GDP']]
# Out:
#                 Population       GDP
# Canada              35.467   1785387
# France              63.951   2833687
# Germany             80.940   3874437
# Italy               60.665   2167744
# Japan              127.061   4602367
# United Kingdom      64.511   2950039
# United States      318.523  17348075

# %%
df[1:3]
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe

# %%
df.loc['Italy']
# Out:
# Population       60.665
# GDP             2167744
# Surface Area     301336
# HDI               0.873
# Continent        Europe
# Name: Italy, dtype: object

# %%
df.loc['France': 'Italy']
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe
# Italy        60.665  2167744        301336  0.873    Europe

# %%
df.iloc[0]
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.loc['France': 'Italy', 'Population'].to_frame()
# Out:
#          Population
# France       63.951
# Germany      80.940
# Italy        60.665

# %%
df.loc['France': 'Italy', ['Population', 'GDP']]
# Out:
#          Population      GDP
# France       63.951  2833687
# Germany      80.940  3874437
# Italy        60.665  2167744

# %%
df.iloc[[0, 1, -1]]
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Canada             35.467   1785387       9984670  0.913   America
# France             63.951   2833687        640679  0.888    Europe
# United States     318.523  17348075       9525067  0.915   America

# %%
df.iloc[1:3]
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe

# %%
df.iloc[1:3, 3]
# Out:
# France     0.888
# Germany    0.916
# Name: HDI, dtype: float64

# %%
df.iloc[1:3, [0, 3]]
# Out:
#          Population    HDI
# France       63.951  0.888
# Germany      80.940  0.916

# %%
df.iloc[1:3, 1:4]
# Out:
#              GDP  Surface Area    HDI
# France   2833687        640679  0.888
# Germany  3874437        357114  0.916

# %%
df['GDP * HDI'] = df['GDP'] * df['HDI']
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent  \
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America
#
#                    GDP * HDI
# Canada          1.630058e+06
# France          2.516314e+06
# Germany         3.548984e+06
# Italy           1.892441e+06
# Japan           4.100709e+06
# United Kingdom  2.675685e+06
# United States   1.587349e+07

# %% [markdown]
# #### Conditional Selection

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent  \
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America
#
#                    GDP * HDI
# Canada          1.630058e+06
# France          2.516314e+06
# Germany         3.548984e+06
# Italy           1.892441e+06
# Japan           4.100709e+06
# United Kingdom  2.675685e+06
# United States   1.587349e+07

# %%
df['Population'] > 70
# Out:
# Canada            False
# France            False
# Germany            True
# Italy             False
# Japan              True
# United Kingdom    False
# United States      True
# Name: Population, dtype: bool

# %%
df.loc[df['Population'] > 70]
# Out:
#                Population       GDP  Surface Area    HDI Continent  \
# Germany            80.940   3874437        357114  0.916    Europe
# Japan             127.061   4602367        377930  0.891      Asia
# United States     318.523  17348075       9525067  0.915   America
#
#                   GDP * HDI
# Germany        3.548984e+06
# Japan          4.100709e+06
# United States  1.587349e+07

# %%
df.loc[df['Population'] > 70, 'Population'].to_frame()
# Out:
#                Population
# Germany            80.940
# Japan             127.061
# United States     318.523

# %%
df.loc[df['Population'] > 70, ['Population', 'GDP']]
# Out:
#                Population       GDP
# Germany            80.940   3874437
# Japan             127.061   4602367
# United States     318.523  17348075

# %% [markdown]
# ### Dropping stuff

# %%
df.drop('Canada')
# Out:
#                 Population       GDP  Surface Area    HDI Continent  \
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America
#
#                    GDP * HDI
# France          2.516314e+06
# Germany         3.548984e+06
# Italy           1.892441e+06
# Japan           4.100709e+06
# United Kingdom  2.675685e+06
# United States   1.587349e+07

# %%
df.drop(['Canada', 'Japan'])
# Out:
#                 Population       GDP  Surface Area    HDI Continent  \
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America
#
#                    GDP * HDI
# France          2.516314e+06
# Germany         3.548984e+06
# Italy           1.892441e+06
# United Kingdom  2.675685e+06
# United States   1.587349e+07

# %%
df.drop(columns=['Population', 'HDI'])
# Out:
#                      GDP  Surface Area Continent     GDP * HDI
# Canada           1785387       9984670   America  1.630058e+06
# France           2833687        640679    Europe  2.516314e+06
# Germany          3874437        357114    Europe  3.548984e+06
# Italy            2167744        301336    Europe  1.892441e+06
# Japan            4602367        377930      Asia  4.100709e+06
# United Kingdom   2950039        242495    Europe  2.675685e+06
# United States   17348075       9525067   America  1.587349e+07

# %%
df.drop(['Italy', 'Canada'], axis=0)
# Out:
#                 Population       GDP  Surface Area    HDI Continent  \
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America
#
#                    GDP * HDI
# France          2.516314e+06
# Germany         3.548984e+06
# Japan           4.100709e+06
# United Kingdom  2.675685e+06
# United States   1.587349e+07

# %%
df.drop(['Population', 'HDI'], axis=1)
# Out:
#                      GDP  Surface Area Continent     GDP * HDI
# Canada           1785387       9984670   America  1.630058e+06
# France           2833687        640679    Europe  2.516314e+06
# Germany          3874437        357114    Europe  3.548984e+06
# Italy            2167744        301336    Europe  1.892441e+06
# Japan            4602367        377930      Asia  4.100709e+06
# United Kingdom   2950039        242495    Europe  2.675685e+06
# United States   17348075       9525067   America  1.587349e+07

# %%
df.drop(['Canada', 'Germany'], axis='rows')
# Out:
#                 Population       GDP  Surface Area    HDI Continent  \
# France              63.951   2833687        640679  0.888    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America
#
#                    GDP * HDI
# France          2.516314e+06
# Italy           1.892441e+06
# Japan           4.100709e+06
# United Kingdom  2.675685e+06
# United States   1.587349e+07

# %% [markdown]
# # Operations

# %%
df[['Population', 'GDP']]
# Out:
#                 Population       GDP
# Canada              35.467   1785387
# France              63.951   2833687
# Germany             80.940   3874437
# Italy               60.665   2167744
# Japan              127.061   4602367
# United Kingdom      64.511   2950039
# United States      318.523  17348075
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['Population'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
df[['Population', 'GDP']] / 100
# Out:
#                 Population        GDP
# Canada             0.35467   17853.87
# France             0.63951   28336.87
# Germany            0.80940   38744.37
# Italy              0.60665   21677.44
# Japan              1.27061   46023.67
# United Kingdom     0.64511   29500.39
# United States      3.18523  173480.75

# %%
crisis = pd.Series([-1_000_000, -0.3], index=['GDP', 'HDI'])
crisis
# Out:
# GDP   -1000000.0
# HDI         -0.3
# dtype: float64

# %%
df[['GDP', 'HDI']]
# Out:
#                      GDP    HDI
# Canada           1785387  0.913
# France           2833687  0.888
# Germany          3874437  0.916
# Italy            2167744  0.873
# Japan            4602367  0.891
# United Kingdom   2950039  0.907
# United States   17348075  0.915

# %%
df[['GDP', 'HDI']] + crisis
# Out:
#                        GDP    HDI
# Canada            785387.0  0.613
# France           1833687.0  0.588
# Germany          2874437.0  0.616
# Italy            1167744.0  0.573
# Japan            3602367.0  0.591
# United Kingdom   1950039.0  0.607
# United States   16348075.0  0.615

# %% [markdown]
# ## Modifying dataframes

# %%
langs = pd.Series(
    ['French', 'German', 'Italian'],
    index=['France', 'Germany', 'Italy'],
    name='Language'
)

# %%
langs
# Out:
# France      French
# Germany     German
# Italy      Italian
# Name: Language, dtype: object

# %%
df['Language'] = langs

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent  \
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America
#
#                    GDP * HDI Language
# Canada          1.630058e+06      NaN
# France          2.516314e+06   French
# Germany         3.548984e+06   German
# Italy           1.892441e+06  Italian
# Japan           4.100709e+06      NaN
# United Kingdom  2.675685e+06      NaN
# United States   1.587349e+07      NaN

# %%
df['Language'] = 'English'
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent  \
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America
#
#                    GDP * HDI Language
# Canada          1.630058e+06  English
# France          2.516314e+06  English
# Germany         3.548984e+06  English
# Italy           1.892441e+06  English
# Japan           4.100709e+06  English
# United Kingdom  2.675685e+06  English
# United States   1.587349e+07  English

# %%
df.rename(
    columns={
        'HDI': 'Human Development Index',
        'Anual Popcorn Consumption': 'APC'
    }, index={
        'United States': 'USA',
        'United Kingdom': 'UK',
        'Argentina': 'AR'
    })
# Out:
#          Population       GDP  Surface Area  Human Development Index  \
# Canada       35.467   1785387       9984670                    0.913
# France       63.951   2833687        640679                    0.888
# Germany      80.940   3874437        357114                    0.916
# Italy        60.665   2167744        301336                    0.873
# Japan       127.061   4602367        377930                    0.891
# UK           64.511   2950039        242495                    0.907
# USA         318.523  17348075       9525067                    0.915
#
#         Continent     GDP * HDI Language
# Canada    America  1.630058e+06  English
# France     Europe  2.516314e+06  English
# Germany    Europe  3.548984e+06  English
# Italy      Europe  1.892441e+06  English
# Japan        Asia  4.100709e+06  English
# UK         Europe  2.675685e+06  English
# USA       America  1.587349e+07  English

# %%
df.rename(index=str.upper)
# Out:
#                 Population       GDP  Surface Area    HDI Continent  \
# CANADA              35.467   1785387       9984670  0.913   America
# FRANCE              63.951   2833687        640679  0.888    Europe
# GERMANY             80.940   3874437        357114  0.916    Europe
# ITALY               60.665   2167744        301336  0.873    Europe
# JAPAN              127.061   4602367        377930  0.891      Asia
# UNITED KINGDOM      64.511   2950039        242495  0.907    Europe
# UNITED STATES      318.523  17348075       9525067  0.915   America
#
#                    GDP * HDI Language
# CANADA          1.630058e+06  English
# FRANCE          2.516314e+06  English
# GERMANY         3.548984e+06  English
# ITALY           1.892441e+06  English
# JAPAN           4.100709e+06  English
# UNITED KINGDOM  2.675685e+06  English
# UNITED STATES   1.587349e+07  English

# %%
df.rename(index=lambda x: x.lower())
# Out:
#                 Population       GDP  Surface Area    HDI Continent  \
# canada              35.467   1785387       9984670  0.913   America
# france              63.951   2833687        640679  0.888    Europe
# germany             80.940   3874437        357114  0.916    Europe
# italy               60.665   2167744        301336  0.873    Europe
# japan              127.061   4602367        377930  0.891      Asia
# united kingdom      64.511   2950039        242495  0.907    Europe
# united states      318.523  17348075       9525067  0.915   America
#
#                    GDP * HDI Language
# canada          1.630058e+06  English
# france          2.516314e+06  English
# germany         3.548984e+06  English
# italy           1.892441e+06  English
# japan           4.100709e+06  English
# united kingdom  2.675685e+06  English
# united states   1.587349e+07  English

# %%
df.drop(columns='Language', inplace=True)

# %%
df.append(pd.Series({
    'Population': 3,
    'GDP': 5
}, name='China'))
# Out:
# <ipython-input-62-52af9b465d5b>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(pd.Series({
#                 Population       GDP  Surface Area    HDI Continent  \
# Canada              35.467   1785387     9984670.0  0.913   America
# France              63.951   2833687      640679.0  0.888    Europe
# Germany             80.940   3874437      357114.0  0.916    Europe
# Italy               60.665   2167744      301336.0  0.873    Europe
# Japan              127.061   4602367      377930.0  0.891      Asia
# United Kingdom      64.511   2950039      242495.0  0.907    Europe
# United States      318.523  17348075     9525067.0  0.915   America
# China                3.000         5           NaN    NaN       NaN
#
#                    GDP * HDI
# Canada          1.630058e+06
# France          2.516314e+06
# Germany         3.548984e+06
# Italy           1.892441e+06
# ...

# %%
df.loc['China'] = pd.Series({'Population': 1_400_000_000, 'Continent': 'Asia'})

# %%
df
# Out:
#                   Population         GDP  Surface Area    HDI Continent  \
# Canada          3.546700e+01   1785387.0     9984670.0  0.913   America
# France          6.395100e+01   2833687.0      640679.0  0.888    Europe
# Germany         8.094000e+01   3874437.0      357114.0  0.916    Europe
# Italy           6.066500e+01   2167744.0      301336.0  0.873    Europe
# Japan           1.270610e+02   4602367.0      377930.0  0.891      Asia
# United Kingdom  6.451100e+01   2950039.0      242495.0  0.907    Europe
# United States   3.185230e+02  17348075.0     9525067.0  0.915   America
# China           1.400000e+09         NaN           NaN    NaN      Asia
#
#                    GDP * HDI
# Canada          1.630058e+06
# France          2.516314e+06
# Germany         3.548984e+06
# Italy           1.892441e+06
# Japan           4.100709e+06
# United Kingdom  2.675685e+06
# United States   1.587349e+07
# China                    NaN

# %%
df.drop('China', inplace=True)

# %%
df
# Out:
#                 Population         GDP  Surface Area    HDI Continent  \
# Canada              35.467   1785387.0     9984670.0  0.913   America
# France              63.951   2833687.0      640679.0  0.888    Europe
# Germany             80.940   3874437.0      357114.0  0.916    Europe
# Italy               60.665   2167744.0      301336.0  0.873    Europe
# Japan              127.061   4602367.0      377930.0  0.891      Asia
# United Kingdom      64.511   2950039.0      242495.0  0.907    Europe
# United States      318.523  17348075.0     9525067.0  0.915   America
#
#                    GDP * HDI
# Canada          1.630058e+06
# France          2.516314e+06
# Germany         3.548984e+06
# Italy           1.892441e+06
# Japan           4.100709e+06
# United Kingdom  2.675685e+06
# United States   1.587349e+07

# %%
df.reset_index()
# Out:
#             index  Population         GDP  Surface Area    HDI Continent  \
# 0          Canada      35.467   1785387.0     9984670.0  0.913   America
# 1          France      63.951   2833687.0      640679.0  0.888    Europe
# 2         Germany      80.940   3874437.0      357114.0  0.916    Europe
# 3           Italy      60.665   2167744.0      301336.0  0.873    Europe
# 4           Japan     127.061   4602367.0      377930.0  0.891      Asia
# 5  United Kingdom      64.511   2950039.0      242495.0  0.907    Europe
# 6   United States     318.523  17348075.0     9525067.0  0.915   America
#
#       GDP * HDI
# 0  1.630058e+06
# 1  2.516314e+06
# 2  3.548984e+06
# 3  1.892441e+06
# 4  4.100709e+06
# 5  2.675685e+06
# 6  1.587349e+07

# %%
df.set_index('Population')
# Out:
#                    GDP  Surface Area    HDI Continent     GDP * HDI
# Population
# 35.467       1785387.0     9984670.0  0.913   America  1.630058e+06
# 63.951       2833687.0      640679.0  0.888    Europe  2.516314e+06
# 80.940       3874437.0      357114.0  0.916    Europe  3.548984e+06
# 60.665       2167744.0      301336.0  0.873    Europe  1.892441e+06
# 127.061      4602367.0      377930.0  0.891      Asia  4.100709e+06
# 64.511       2950039.0      242495.0  0.907    Europe  2.675685e+06
# 318.523     17348075.0     9525067.0  0.915   America  1.587349e+07

# %%
df
# Out:
#                 Population         GDP  Surface Area    HDI Continent  \
# Canada              35.467   1785387.0     9984670.0  0.913   America
# France              63.951   2833687.0      640679.0  0.888    Europe
# Germany             80.940   3874437.0      357114.0  0.916    Europe
# Italy               60.665   2167744.0      301336.0  0.873    Europe
# Japan              127.061   4602367.0      377930.0  0.891      Asia
# United Kingdom      64.511   2950039.0      242495.0  0.907    Europe
# United States      318.523  17348075.0     9525067.0  0.915   America
#
#                    GDP * HDI
# Canada          1.630058e+06
# France          2.516314e+06
# Germany         3.548984e+06
# Italy           1.892441e+06
# Japan           4.100709e+06
# United Kingdom  2.675685e+06
# United States   1.587349e+07

# %%
df[['Population', 'GDP']]
# Out:
#                 Population         GDP
# Canada              35.467   1785387.0
# France              63.951   2833687.0
# Germany             80.940   3874437.0
# Italy               60.665   2167744.0
# Japan              127.061   4602367.0
# United Kingdom      64.511   2950039.0
# United States      318.523  17348075.0

# %%
df['GDP'] / df['Population']
# Out:
# Canada            50339.385908
# France            44310.284437
# Germany           47868.013343
# Italy             35733.025633
# Japan             36221.712406
# United Kingdom    45729.239975
# United States     54464.120330
# dtype: float64

# %%
df['GDP Per Capita'] = df['GDP'] / df['Population']
df
# Out:
#                 Population         GDP  Surface Area    HDI Continent  \
# Canada              35.467   1785387.0     9984670.0  0.913   America
# France              63.951   2833687.0      640679.0  0.888    Europe
# Germany             80.940   3874437.0      357114.0  0.916    Europe
# Italy               60.665   2167744.0      301336.0  0.873    Europe
# Japan              127.061   4602367.0      377930.0  0.891      Asia
# United Kingdom      64.511   2950039.0      242495.0  0.907    Europe
# United States      318.523  17348075.0     9525067.0  0.915   America
#
#                    GDP * HDI  GDP Per Capita
# Canada          1.630058e+06    50339.385908
# France          2.516314e+06    44310.284437
# Germany         3.548984e+06    47868.013343
# Italy           1.892441e+06    35733.025633
# Japan           4.100709e+06    36221.712406
# United Kingdom  2.675685e+06    45729.239975
# United States   1.587349e+07    54464.120330

# %%
df.head()
# Out:
#          Population        GDP  Surface Area    HDI Continent    GDP * HDI  \
# Canada       35.467  1785387.0     9984670.0  0.913   America  1630058.331
# France       63.951  2833687.0      640679.0  0.888    Europe  2516314.056
# Germany      80.940  3874437.0      357114.0  0.916    Europe  3548984.292
# Italy        60.665  2167744.0      301336.0  0.873    Europe  1892440.512
# Japan       127.061  4602367.0      377930.0  0.891      Asia  4100708.997
#
#          GDP Per Capita
# Canada     50339.385908
# France     44310.284437
# Germany    47868.013343
# Italy      35733.025633
# Japan      36221.712406

# %%
df.describe()
# Out:
#        Population           GDP  Surface Area       HDI     GDP * HDI  \
# count    7.000000  7.000000e+00  7.000000e+00  7.000000  7.000000e+00
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429  4.605383e+06
# std     97.249970  5.494020e+06  4.576187e+06  0.016592  5.043832e+06
# min     35.467000  1.785387e+06  2.424950e+05  0.873000  1.630058e+06
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500  2.204377e+06
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000  2.675685e+06
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000  3.824847e+06
# max    318.523000  1.734808e+07  9.984670e+06  0.916000  1.587349e+07
#
#        GDP Per Capita
# count        7.000000
# mean     44952.254576
# std       6954.983875
# min      35733.025633
# 25%      40265.998421
# 50%      45729.239975
# 75%      49103.699626
# max      54464.120330

# %%
df['Population'].max()
# Out:
# 318.523

# %%
df['Population'].min()
# Out:
# 35.467
